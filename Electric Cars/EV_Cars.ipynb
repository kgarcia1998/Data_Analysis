# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("EV_cars.csv", index_col=0)

# %%
# Out:
#                                     Car_name  \
# Battery
# 75.0     Tesla Model Y Long Range Dual Motor
# 57.5                           Tesla Model 3
# 60.5                              BYD ATTO 3
# 61.7                  MG MG4 Electric 64 kWh
# 75.0     Tesla Model 3 Long Range Dual Motor
# ...                                      ...
# 46.3         Citroen e-Jumpy Combi XL 50 kWh
# 46.3                 Fiat E-Ulysse L2 50 kWh
# 46.3            Opel Vivaro-e Combi L 50 kWh
# 68.0             Opel Zafira-e Life M 75 kWh
# 46.3                 Fiat E-Ulysse L3 50 kWh
#
#                                              Car_name_link  Efficiency  \
# Battery
# 75.0     https://ev-database.org/car/1619/Tesla-Model-Y...         172
# 57.5        https://ev-database.org/car/1991/Tesla-Model-3         137
# 60.5           https://ev-database.org/car/1782/BYD-ATTO-3         183
# 61.7     https://ev-database.org/car/1708/MG-MG4-Electr...         171
# ...
